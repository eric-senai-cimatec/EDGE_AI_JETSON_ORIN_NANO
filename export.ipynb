# %%
from ultralytics import YOLO

# %%
# Load a YOLO26 model
model = YOLO("runs/detect/train/weights/best.pt")  # load a custom model

# %%
# Export the model to TensorRT format
model.export(format="engine", workspace=2, batch=1, device="cuda", 
             half=True, dynamic=False, nms=False, imgsz=640)
# Out:
# Ultralytics 8.3.235 🚀 Python-3.10.12 torch-2.5.0a0+872d972e41.nv24.08 CUDA:0 (Orin, 7620MiB)
# YOLO26n summary (fused): 146 layers, 2,498,594 parameters, 0 gradients, 5.2 GFLOPs
#
# PyTorch: starting from 'runs/detect/train/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 15, 8400) (5.2 MB)
# requirements: Ultralytics requirements ['onnx>=1.12.0,<=1.19.1', 'onnxruntime-gpu'] not found, attempting AutoUpdate...
# WARNING ⚠️ Retry 1/2 failed: Command 'pip install --no-cache-dir "onnx>=1.12.0,<=1.19.1" "onnxruntime-gpu" ' returned non-zero exit status 1.
# WARNING ⚠️ Retry 2/2 failed: Command 'pip install --no-cache-dir "onnx>=1.12.0,<=1.19.1" "onnxruntime-gpu" ' returned non-zero exit status 1.
# WARNING ⚠️ requirements: ❌ Command 'pip install --no-cache-dir "onnx>=1.12.0,<=1.19.1" "onnxruntime-gpu" ' returned non-zero exit status 1.
#
# ONNX: starting export with onnx 1.22.0 opset 17...
# 2026-08-27 12:13:07.414385114 [W:onnxruntime:Default, device_discovery.cc:164 DiscoverDevicesForPlatform] GPU device discovery failed: device_discovery.cc:89 ReadFileContents Failed to open file: "/sys/class/drm/card1/device/vendor"
# ONNX: slimming with onnxslim 0.1.96...
# ONNX: export success ✅ 186.3s, saved as 'runs/detect/train/weights/best.onnx' (9.3 MB)
#
# TensorRT: starting export with TensorRT 10.3.0...
# [08/27/2026-12:13:11] [TRT] [I] [MemUsageChange] Init CUDA: CPU +2, GPU +0, now: CPU 637, GPU 4906 (MiB)
# [08/27/2026-12:13:16] [TRT] [I] [MemUsageChange] Init builder kernel library: CPU +927, GPU +982, now: CPU 1607, GPU 5932 (MiB)
# [08/27/2026-12:13:16] [TRT] [I] ----------------------------------------------------------------
# [08/27/2026-12:13:16] [TRT] [I] Input filename:   runs/detect/train/weights/best.onnx
# [08/27/2026-12:13:16] [TRT] [I] ONNX IR version:  0.0.8
# [08/27/2026-12:13:16] [TRT] [I] Opset version:    17
# [08/27/2026-12:13:16] [TRT] [I] Producer name:    pytorch
# [08/27/2026-12:13:16] [TRT] [I] Producer version: 2.5.0
# [08/27/2026-12:13:16] [TRT] [I] Domain:
# [08/27/2026-12:13:16] [TRT] [I] Model version:    0
# [08/27/2026-12:13:16] [TRT] [I] Doc string:
# [08/27/2026-12:13:16] [TRT] [I] ----------------------------------------------------------------
# TensorRT: input "images" with shape(1, 3, 640, 640) DataType.FLOAT
# TensorRT: output "output0" with shape(1, 15, 8400) DataType.FLOAT
# TensorRT: building FP16 engine as runs/detect/train/weights/best.engine
# [08/27/2026-12:13:16] [TRT] [I] Local timing cache in use. Profiling results in this builder pass will not be stored.
# [08/27/2026-12:22:38] [TRT] [I] Detected 1 inputs and 3 output network tensors.
# [08/27/2026-12:22:45] [TRT] [I] Total Host Persistent Memory: 595536
# [08/27/2026-12:22:45] [TRT] [I] Total Device Persistent Memory: 2048
# [08/27/2026-12:22:45] [TRT] [I] Total Scratch Memory: 2764800
# [08/27/2026-12:22:45] [TRT] [I] [BlockAssignment] Started assigning block shifts. This will take 195 steps to complete.
# [08/27/2026-12:22:45] [TRT] [I] [BlockAssignment] Algorithm ShiftNTopDown took 19.565ms to assign 11 blocks to 195 nodes requiring 9626112 bytes.
# [08/27/2026-12:22:45] [TRT] [I] Total Activation Memory: 9625600
# [08/27/2026-12:22:45] [TRT] [I] Total Weights Memory: 4900484
# [08/27/2026-12:22:46] [TRT] [I] Engine generation completed in 569.069 seconds.
# [08/27/2026-12:22:46] [TRT] [I] [MemUsageStats] Peak memory usage of TRT CPU/GPU memory allocators: CPU 0 MiB, GPU 50 MiB
# [08/27/2026-12:22:46] [TRT] [I] [MemUsageStats] Peak memory usage during Engine building and serialization: CPU: 2885 MiB
# TensorRT: export success ✅ 761.6s, saved as 'runs/detect/train/weights/best.engine' (7.9 MB)
#
# Export complete (763.9s)
# Results saved to /home/nano/Documents/EDGE_AI_JETSON_ORIN_NANO/runs/detect/train/weights
# Predict:         yolo predict task=detect model=runs/detect/train/weights/best.engine imgsz=640 half
# Validate:        yolo val task=detect model=runs/detect/train/weights/best.engine imgsz=640 data=construction-ppe.yaml half
# Visualize:       https://netron.app
# 'runs/detect/train/weights/best.engine'
