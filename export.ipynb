# %%
from ultralytics import YOLO

# %%
# Load a YOLO26 model
model = YOLO("runs/detect/train/weights/best.pt")  # load a custom model

# %%
# Export the model to TensorRT format
model.export(format="engine", workspace=2, device="cuda", half=True, imgsz=640, end2end=False)
# Out:
# WARNING ⚠️ 'half' is deprecated and will be removed in the future. Use 'quantize' instead.
# Ultralytics 8.4.138 🚀 Python-3.10.12 torch-2.8.0 CUDA:0 (Orin, 7619MiB)
# YOLO26n summary (fused): 146 layers, 2,498,594 parameters, 0 gradients, 5.3 GFLOPs
#
# PyTorch: starting from 'runs/detect/train/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 15, 8400) (5.2 MB)
#
# ONNX: starting export with onnx 1.22.0 opset 18...
# ONNX: slimming with onnxslim 0.1.96...
# 2026-09-03 14:08:12.129401622 [W:onnxruntime:Default, device_discovery.cc:164 DiscoverDevicesForPlatform] GPU device discovery failed: device_discovery.cc:89 ReadFileContents Failed to open file: "/sys/class/drm/card0/device/vendor"
# ONNX: export success ✅ 4.0s, saved as 'runs/detect/train/weights/best.onnx' (9.3 MB)
#
# TensorRT: starting export with TensorRT 10.3.0...
# [09/03/2026-14:08:13] [TRT] [I] [MemUsageChange] Init CUDA: CPU +2, GPU +0, now: CPU 654, GPU 4859 (MiB)
# [09/03/2026-14:08:15] [TRT] [I] [MemUsageChange] Init builder kernel library: CPU +927, GPU +734, now: CPU 1624, GPU 5625 (MiB)
# [09/03/2026-14:08:15] [TRT] [I] ----------------------------------------------------------------
# [09/03/2026-14:08:15] [TRT] [I] Input filename:   runs/detect/train/weights/best.onnx
# [09/03/2026-14:08:15] [TRT] [I] ONNX IR version:  0.0.8
# [09/03/2026-14:08:15] [TRT] [I] Opset version:    18
# [09/03/2026-14:08:15] [TRT] [I] Producer name:    pytorch
# [09/03/2026-14:08:15] [TRT] [I] Producer version: 2.8.0
# [09/03/2026-14:08:15] [TRT] [I] Domain:
# [09/03/2026-14:08:15] [TRT] [I] Model version:    0
# [09/03/2026-14:08:15] [TRT] [I] Doc string:
# [09/03/2026-14:08:15] [TRT] [I] ----------------------------------------------------------------
# TensorRT: input "images" with shape(1, 3, 640, 640) DataType.FLOAT
# TensorRT: output "output0" with shape(1, 15, 8400) DataType.FLOAT
# TensorRT: building FP16 engine as runs/detect/train/weights/best.engine
# [09/03/2026-14:08:16] [TRT] [I] Local timing cache in use. Profiling results in this builder pass will not be stored.
# [09/03/2026-14:15:47] [TRT] [I] Detected 1 inputs and 3 output network tensors.
# [09/03/2026-14:15:52] [TRT] [I] Total Host Persistent Memory: 608752
# [09/03/2026-14:15:52] [TRT] [I] Total Device Persistent Memory: 0
# [09/03/2026-14:15:52] [TRT] [I] Total Scratch Memory: 1382400
# [09/03/2026-14:15:52] [TRT] [I] [BlockAssignment] Started assigning block shifts. This will take 190 steps to complete.
# [09/03/2026-14:15:52] [TRT] [I] [BlockAssignment] Algorithm ShiftNTopDown took 20.5222ms to assign 12 blocks to 190 nodes requiring 9524224 bytes.
# [09/03/2026-14:15:52] [TRT] [I] Total Activation Memory: 9523200
# [09/03/2026-14:15:52] [TRT] [I] Total Weights Memory: 4898564
# [09/03/2026-14:15:52] [TRT] [I] Engine generation completed in 456.229 seconds.
# [09/03/2026-14:15:52] [TRT] [I] [MemUsageStats] Peak memory usage of TRT CPU/GPU memory allocators: CPU 0 MiB, GPU 50 MiB
# [09/03/2026-14:15:52] [TRT] [I] [MemUsageStats] Peak memory usage during Engine building and serialization: CPU: 2833 MiB
# TensorRT: export success ✅ 463.3s, saved as 'runs/detect/train/weights/best.engine' (8.0 MB)
#
# Export complete (464.7s)
# Results saved to /home/nano/Documents/EDGE_AI_JETSON_ORIN_NANO/runs/detect/train/weights/best.engine
# Predict:         yolo predict task=detect model=runs/detect/train/weights/best.engine imgsz=640 quantize=16
# Validate:        yolo val task=detect model=runs/detect/train/weights/best.engine imgsz=640 data=construction-ppe.yaml quantize=16
# Visualize:       https://netron.app
# PosixPath('runs/detect/train/weights/best.engine')
